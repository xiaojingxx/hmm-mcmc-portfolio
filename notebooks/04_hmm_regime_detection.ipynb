# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

# %%
import pandas as pd

features = pd.read_csv(
    "../data/processed/feature_matrix.csv",
    index_col=0,
    parse_dates=True
)

features.head()
# Out:
#             AAPL_ret    BA_ret   BND_ret    CL_ret    GC_ret   JNJ_ret  \
# Date
# 2015-02-02  0.012469  0.006104 -0.001189  0.021538  0.000000  0.006867
# 2015-02-03  0.000169  0.007357 -0.003096  0.002895  0.024332  0.016037
# 2015-02-04  0.007641 -0.000815  0.000357  0.000144  0.000000 -0.010794
# 2015-02-05  0.007112  0.009330 -0.002149  0.008490  0.004796  0.010794
# 2015-02-06 -0.008457 -0.004046 -0.006475 -0.007046 -0.009615 -0.013363
#
#              JPM_ret    KO_ret  MSFT_ret  NVDA_ret  ...   JNJ_mom   JPM_mom  \
# Date                                                ...
# 2015-02-02  0.019846  0.010150  0.021549  0.021639  ... -0.035304 -0.112338
# 2015-02-03  0.022285  0.000961  0.007722  0.024668  ... -0.012814 -0.063254
# 2015-02-04 -0.006012  0.001200  0.005752  0.002483  ... -0.018590 -0.044083
# 2015-02-05  0.006893  0.002636  0.014474  0.016236  ... -0.029367 -0.038937
# 2015-02-06  0.019537 -0.008169 -0.000943 -0.004402  ... -0.049723 -0.041397
#
#               KO_mom  MSFT_mom  NVDA_mom   PEP_mom   QQQ_mom   SPY_mom  \
# Date
# 2015-02-02 -0.013051 -0.117194 -0.025335  0.009424 -0.009326 -0.017086
# 2015-02-03 -0.012102 -0.102093  0.016170  0.026352  0.015084  0.015467
# 2015-02-04 -0.018370 -0.083462  0.050547  0.038486  0.027981  0.021219
# 2015-02-05 -0.027913 -0.081765  0.070532  0.009087  0.023678  0.018832
# 2015-02-06 -0.047345 -0.108846  0.027190 -0.007899 -0.001646 -0.001700
#
#              TLT_mom  TSLA_mom
# Date
# 2015-02-02  0.081982 -0.038165
# 2015-02-03  0.042701  0.039364
# 2015-02-04  0.025997  0.034409
# 2015-02-05  0.016741  0.047594
# 2015-02-06  0.012146  0.032001
#
# [5 rows x 45 columns]

# %%
import re

pattern = re.compile(r'^([A-Z]+)')

# Extract asset names
assets = set()
for col in features.columns:
    match = pattern.match(col)
    if match:
        assets.add(match.group(1))

assets = sorted(list(assets))

# %%
assets
# Out:
# ['AAPL',
#  'BA',
#  'BND',
#  'CL',
#  'GC',
#  'JNJ',
#  'JPM',
#  'KO',
#  'MSFT',
#  'NVDA',
#  'PEP',
#  'QQQ',
#  'SPY',
#  'TLT',
#  'TSLA']

# %%
from scripts.models.hmm_utils import fit_hmm_for_asset, add_risk_scaling

# %%
for asset in assets:
    hmm_df, _, _ = fit_hmm_for_asset(features, asset)
    hmm_df = add_risk_scaling(hmm_df, asset)

    out_path = f"../data/processed/hmm_{asset}.csv"
    hmm_df.to_csv(out_path)

    print(f"Saved {out_path}")
# Out:
# Model is not converging.  Current: 58208.061530561914 is not greater than 58216.93610954817. Delta is -8.874578986258712
# AAPL: final log-likelihood = -5917.5193
# Saved ../data/processed/hmm_AAPL.csv
# BA: final log-likelihood = -5241.4985
# Saved ../data/processed/hmm_BA.csv
# BND: final log-likelihood = -4907.7162
# Saved ../data/processed/hmm_BND.csv
# CL: final log-likelihood = -5923.5035
# Saved ../data/processed/hmm_CL.csv
# GC: final log-likelihood = 58208.0615
# Saved ../data/processed/hmm_GC.csv
# JNJ: final log-likelihood = -5687.2306
# Saved ../data/processed/hmm_JNJ.csv
# JPM: final log-likelihood = -5392.7245
# Saved ../data/processed/hmm_JPM.csv
# KO: final log-likelihood = -5501.6926
# Saved ../data/processed/hmm_KO.csv
# MSFT: final log-likelihood = -5903.8102
# Saved ../data/processed/hmm_MSFT.csv
# NVDA: final log-likelihood = -5757.6544
# Saved ../data/processed/hmm_NVDA.csv
# PEP: final log-likelihood = -5396.3836
# Saved ../data/processed/hmm_PEP.csv
# QQQ: final log-likelihood = -5574.3553
# Saved ../data/processed/hmm_QQQ.csv
# SPY: final log-likelihood = -5206.9086
# Saved ../data/processed/hmm_SPY.csv
# TLT: final log-likelihood = -5949.3919
# Saved ../data/processed/hmm_TLT.csv
# TSLA: final log-likelihood = -6076.4147
# Saved ../data/processed/hmm_TSLA.csv
